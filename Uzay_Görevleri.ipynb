# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install iso3166
# !pip install plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from iso3166 import countries
import plotly.express as xp
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ccd27b2-1355-425c-a7c2-6ca6a513f47c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ccd27b2-1355-425c-a7c2-6ca6a513f47c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("Space_Corrected.csv")
data.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
# 5             5           5         CASC
# 6             6           6    Roscosmos
# 7             7           7         CASC
# 8             8           8       SpaceX
# 9             9           9         JAXA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
# 5       LC-9, Taiyuan Satellite Launch Center, China
# 6         Site 31/6, Baikonur Cosmodrome, Kazakhstan
# 7    LC-101, Wenchang Satellite Launch Center, China
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0
# count   4324.000000  4324.000000
# mean    2161.500000  2161.500000
# std     1248.375611  1248.375611
# min        0.000000     0.000000
# 25%     1080.750000  1080.750000
# 50%     2161.500000  2161.500000
# 75%     3242.250000  3242.250000
# max     4323.000000  4323.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    4324 non-null   int64
#  1   Unnamed: 0      4324 non-null   int64
#  2   Company Name    4324 non-null   object
#  3   Location        4324 non-null   object
#  4   Datum           4324 non-null   object
#  5   Detail          4324 non-null   object
#  6   Status Rocket   4324 non-null   object
#  7    Rocket         964 non-null    object
#  8   Status Mission  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB

# %%
data["Company Name"].value_counts().head(10)
# Out:
# Company Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# Name: count, dtype: int64

# %%
yeni=data["Company Name"].value_counts().reset_index()
yeni.columns = ["index", "Company Name"]
yeni.head(10)
# Out:
#               index  Company Name
# 0         RVSN USSR          1777
# 1       Arianespace           279
# 2              CASC           251
# 3  General Dynamics           251
# 4              NASA           203
# 5            VKS RF           201
# 6      US Air Force           161
# 7               ULA           140
# 8            Boeing           136
# 9   Martin Marietta           114

# %%
fig=go.Figure(go.Bar(x=yeni["index"],y=yeni["Company Name"]))
fig.update_layout(title="şirketler",xaxis_title="Ülkeler",yaxis_title="Gönderim sayısı",hovermode="x")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
yeni1=data["Status Rocket"].value_counts().reset_index()
yeni1.columns = ["index", "Status Rocket"]
yeni1
# Out:
#            index  Status Rocket
# 0  StatusRetired           3534
# 1   StatusActive            790

# %%
fig=xp.pie(yeni1,values="Status Rocket",names="index",title="Status Rocket")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
yeni2=data["Status Mission"].value_counts().reset_index()  #RESET İNDEX TABLONUN YANINA İNDEX EKLER (EKSTRA BAŞLIK VERMEYİ UNUTMA)
yeni2.columns = ["index","Status Mission"]
yeni2
# Out:
#                index  Status Mission
# 0            Success            3879
# 1            Failure             339
# 2    Partial Failure             102
# 3  Prelaunch Failure               4

# %%
fig=xp.bar(yeni2,x="index",y="Status Mission",title="Görev Durumu")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
pd.isnull(data.loc[: "Rocket"])  #0 DAN ROCKET E  KADAR BOŞ DEĞERLERİ BUL
# Out:
#       Unnamed: 0.1  Unnamed: 0  Company Name  Location  Datum  Detail  \
# 0            False       False         False     False  False   False
# 1            False       False         False     False  False   False
# 2            False       False         False     False  False   False
# 3            False       False         False     False  False   False
# 4            False       False         False     False  False   False
# ...            ...         ...           ...       ...    ...     ...
# 4319         False       False         False     False  False   False
# 4320         False       False         False     False  False   False
# 4321         False       False         False     False  False   False
# 4322         False       False         False     False  False   False
# 4323         False       False         False     False  False   False
#
#       Status Rocket   Rocket  Status Mission
# 0             False    False           False
# ...

# %%
np.sum(pd.isnull(data.loc[: "Rocket"])) #TOPLAM BOŞ VERİ  NE KADAR
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning:
#
# The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
# Unnamed: 0.1         0
# Unnamed: 0           0
# Company Name         0
# Location             0
# Datum                0
# Detail               0
# Status Rocket        0
#  Rocket           3360
# Status Mission       0
# dtype: int64

# %%
yeni3=data.dropna(subset=[" Rocket"],axis=0)
len(yeni3)
# Out:
# 964

# %%
yeni3[" Rocket"] = yeni3[" Rocket"].fillna(0.0).astype(str).str.replace(",", "")

yeni3[" Rocket"] = yeni3[" Rocket"].astype(str).str.replace(",", "").astype(np.float64).fillna(0) #BURAYI TEKRAR ET
# Out:
# <ipython-input-40-44702476a642>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-40-44702476a642>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head(11)
# Out:
#     Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0              0           0       SpaceX
# 1              1           1         CASC
# 2              2           2       SpaceX
# 3              3           3    Roscosmos
# 4              4           4          ULA
# 5              5           5         CASC
# 6              6           6    Roscosmos
# 7              7           7         CASC
# 8              8           8       SpaceX
# 9              9           9         JAXA
# 10            10          10     Northrop
#
#                                              Location  \
# 0          LC-39A, Kennedy Space Center, Florida, USA
# 1   Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                       Pad A, Boca Chica, Texas, USA
# 3        Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4            SLC-41, Cape Canaveral AFS, Florida, USA
# 5        LC-9, Taiyuan Satellite Launch Center, China
# 6          Site 31/6, Baikonur Cosmodrome, Kazakhstan
# ...

# %%
data.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)    #İLK 2 GEREKSİZ SATIRI ATTIK
data.head(11)
# Out:
#    Company Name                                           Location  \
# 0        SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1          CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        SpaceX                      Pad A, Boca Chica, Texas, USA
# 3     Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5          CASC       LC-9, Taiyuan Satellite Launch Center, China
# 6     Roscosmos         Site 31/6, Baikonur Cosmodrome, Kazakhstan
# 7          CASC    LC-101, Wenchang Satellite Launch Center, China
# 8        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 9          JAXA             LA-Y1, Tanegashima Space Center, Japan
# 10     Northrop      LP-0B, Wallops Flight Facility, Virginia, USA
#
#                          Datum  \
# 0   Fri Aug 07, 2020 05:12 UTC
# 1   Thu Aug 06, 2020 04:01 UTC
# 2   Tue Aug 04, 2020 23:57 UTC
# ...

# %%
yeni3
# Out:
#       Unnamed: 0.1  Unnamed: 0  Company Name  \
# 0                0           0        SpaceX
# 1                1           1          CASC
# 3                3           3     Roscosmos
# 4                4           4           ULA
# 5                5           5          CASC
# ...            ...         ...           ...
# 3855          3855        3855  US Air Force
# 3971          3971        3971  US Air Force
# 3993          3993        3993  US Air Force
# 4000          4000        4000  US Air Force
# 4020          4020        4020  US Air Force
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# 5          LC-9, Taiyuan Satellite Launch Center, China
# ...                                                 ...
# ...

# %%
yeni3.groupby("Company Name")[" Rocket"].sum().round().sort_values(ascending=False)   #COMPANY NAME İ ROCKET DEGRLERİNİN TOPLAMLARINA GÖRE SIRALADIK
# Out:
# Company Name
# NASA               76280.0
# Arianespace        16345.0
# ULA                14798.0
# RVSN USSR          10000.0
# CASC                6340.0
# SpaceX              5444.0
# Northrop            3930.0
# MHI                 3532.0
# ISRO                2177.0
# US Air Force        1551.0
# VKS RF              1549.0
# ILS                 1320.0
# Boeing              1241.0
# Roscosmos           1188.0
# Martin Marietta      721.0
# Kosmotras            638.0
# Eurockot             543.0
# Lockheed             280.0
# JAXA                 168.0
# Rocket Lab            98.0
# ESA                   37.0
# ExPace                28.0
# EER                   20.0
# Sandia                15.0
# Virgin Orbit          12.0
# Name:  Rocket, dtype: float64

# %%
money1=yeni3.groupby("Company Name")[" Rocket"].sum().reset_index()
money1.head()
# Out:
#   Company Name    Rocket
# 0  Arianespace  16345.00
# 1       Boeing   1241.00
# 2         CASC   6340.26
# 3          EER     20.00
# 4          ESA     37.00

# %%
money1=money1.sort_values(by=[" Rocket"],ascending=False)
money1.head(11)
# Out:
#     Company Name    Rocket
# 14          NASA  76280.00
# 0    Arianespace  16345.00
# 21           ULA  14798.00
# 16     RVSN USSR  10000.00
# 2           CASC   6340.26
# 20        SpaceX   5444.00
# 15      Northrop   3930.00
# 12           MHI   3532.50
# 8           ISRO   2177.00
# 22  US Air Force   1550.92
# 23        VKS RF   1548.90

# %%
fig=xp.bar(money1,x="Company Name",y=" Rocket",title="Toplam Harcanan Para")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.head(11)
# Out:
#    Company Name                                           Location  \
# 0        SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1          CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        SpaceX                      Pad A, Boca Chica, Texas, USA
# 3     Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5          CASC       LC-9, Taiyuan Satellite Launch Center, China
# 6     Roscosmos         Site 31/6, Baikonur Cosmodrome, Kazakhstan
# 7          CASC    LC-101, Wenchang Satellite Launch Center, China
# 8        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 9          JAXA             LA-Y1, Tanegashima Space Center, Japan
# 10     Northrop      LP-0B, Wallops Flight Facility, Virginia, USA
#
#                          Datum  \
# 0   Fri Aug 07, 2020 05:12 UTC
# 1   Thu Aug 06, 2020 04:01 UTC
# 2   Tue Aug 04, 2020 23:57 UTC
# ...

# %%
data["Date"] = pd.to_datetime(data["Datum"], format="%a %b %d, %Y %H:%M %Z", errors="coerce")


data.head(11)
# Out:
#    Company Name                                           Location  \
# 0        SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1          CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        SpaceX                      Pad A, Boca Chica, Texas, USA
# 3     Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5          CASC       LC-9, Taiyuan Satellite Launch Center, China
# 6     Roscosmos         Site 31/6, Baikonur Cosmodrome, Kazakhstan
# 7          CASC    LC-101, Wenchang Satellite Launch Center, China
# 8        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 9          JAXA             LA-Y1, Tanegashima Space Center, Japan
# 10     Northrop      LP-0B, Wallops Flight Facility, Virginia, USA
#
#                          Datum  \
# 0   Fri Aug 07, 2020 05:12 UTC
# 1   Thu Aug 06, 2020 04:01 UTC
# 2   Tue Aug 04, 2020 23:57 UTC
# ...

# %%
data["year"]=data["Date"].apply(lambda datetime:datetime.year)
data.head()
# Out:
#   Company Name                                           Location  \
# 0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission                      Date    year
# ...

# %%
yillar=data["year"].value_counts().reset_index()
yillar.columns=["index","year"]
yillar
# Out:
#      index  year
# 0   2018.0   117
# 1   1971.0   116
# 2   1975.0   112
# 3   1976.0   109
# 4   1977.0   109
# ..     ...   ...
# 59  2010.0    36
# 60  2012.0    34
# 61  1958.0    22
# 62  1959.0    20
# 63  1957.0     3
#
# [64 rows x 2 columns]

# %%
fig=xp.bar(yillar,x="index",y="year",title="Yıllara göre görevler")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.head()
# Out:
#   Company Name                                           Location  \
# 0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission                      Date    year
# ...

# %%
ulkeler={
    "Russia":"Russian Federation",
    "New Mexico":"USA",
    "Yellow Sea":"china",
    "Shahrud Missile Test Side":"Iran",
    "Pasific Missile Range Facility":"USA",
    "Barents Sea":"Russian Federation",
    "Gran Canaria":"USA"
    }

# %%
data["country"]=data["Location"].str.split(",").str[-1].replace(ulkeler)
data.head()
# Out:
#   Company Name                                           Location  \
# 0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission                      Date    year  \
# ...

# %%
sun=data.groupby(["country","Company Name","Status Mission"])["Datum"].count().reset_index()  #ÜLKELERİ AYIRDIK
sun
# Out:
#          country  Company Name   Status Mission  Datum
# 0      Australia          AMBA          Success      1
# 1      Australia        CECLES          Failure      2
# 2      Australia        CECLES          Success      1
# 3      Australia           RAE          Failure      1
# 4      Australia           RAE          Success      1
# ..           ...           ...              ...    ...
# 129          USA       US Navy          Failure     14
# 130          USA       US Navy  Partial Failure      1
# 131          USA       US Navy          Success      2
# 132          USA  Virgin Orbit          Failure      1
# 133   Yellow Sea          CASC          Success      1
#
# [134 rows x 4 columns]

# %%
fig=xp.sunburst(sun,path=["country","Company Name","Status Mission"],values="Datum",title="Güneşi gören Ülkleer")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
